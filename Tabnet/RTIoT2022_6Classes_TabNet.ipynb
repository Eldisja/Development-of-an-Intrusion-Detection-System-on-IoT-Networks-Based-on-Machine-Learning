# %%
# !pip install -q pytorch-tabular

# %%
# Menambahkan path direktori Kode_Skripsi untuk mengimpor file functions.py
import sys
sys.path.append('/content/drive/MyDrive/Kode_Skripsi')

# %%
# !cp /content/drive/MyDrive/Kode_Skripsi/functions.py /content/

# %% [markdown]
# Preprocessing

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import f1_score, precision_score, roc_auc_score,log_loss, accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.utils.class_weight import compute_class_weight

import torch
import os
import functions

# %%
# Mengabaikan warning penggunaan processor dan konfigurasi penggunaan weight terbaik dari epoch sebelumnya
functions.ignore_warnings()

# %%
# Mengambil dataset RT IoT 2022
rt_iot2022_6classes = '/content/drive/MyDrive/Dataset_Skripsi/6_Classes/RT_IOT2022_6Classes.csv'

df = pd.read_csv(rt_iot2022_6classes)

# Memisahkan kolom fitur dan target
X = df.drop(columns=['Attack_type'])
y = df['Attack_type']

# %%
# Menyimpan label asli sebelum encoding agar tidak ikut termodifikasi
y_label = y.copy()

# Melakukan encoding label utama (y) sekali untuk StratifiedKFold
y_encoded = LabelEncoder().fit_transform(y.squeeze())

# %%
# Menampilkan hasil encoding
functions.show_label_encoding(y, y_encoded)
# Out:
# ===== Mapping Label Encoding (Attack_type) =====
#      Label_Original  Label_Encoded
#      ARP_poisioning              0
#      DDOS_Slowloris              1
#   NMAP_OS_DETECTION              2
#       NMAP_TCP_scan              3
#       NMAP_UDP_SCAN              4
# NMAP_XMAS_TREE_SCAN              5

# %% [markdown]
# ##TabNet

# %%
# Melakukan Stratified K-Fold dengan 5 fold dan hasilnya diacak
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Memastikan folder Model_Skripsi tersedia
os.makedirs("/content/drive/MyDrive/Model_Skripsi/", exist_ok=True)

# %%
# Melakukan inisialisasi untuk menyimpan kurva metrik per epoch dalam setiap fold
fold_logloss_curve = []
fold_accuracy_curve = []

# Melakukan inisialisasi untuk nantinya menyimpan metrik setiap fold
fold_results = {
    'fold': [],
    'accuracy': [],
    'f1_score': [],
    'precision': [],
    'roc_auc': [],
    'log_loss': []
}

# Melakukan inisialisasi model terbaik
best_model_path = ""

best_logloss = float('inf')
best_y_true = None
best_preds = None

# Melakukan inisialisasi untuk nilai epoch dan patience yang sedang digunakan
n_epochs=50
n_patience=15

# Melakukan Cross-validation
for fold, (train_idx, test_idx) in enumerate(skf.split(X, y_encoded)):
    print(f"\nFold {fold+1}")

    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    # Melakukan encoding dan scaling
    X_train_np, X_test_np, y_train_np, y_test_np = functions.encoding_rt_iot22_balanced(X_train, X_test, y_train, y_test)


    # Menggunakan compute class weights untuk bobot balancing dataset
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_np),
        y=y_train_np
    )
    sample_weights = class_weights[y_train_np]

    # Melakukan training TabNet
    tabnet_model = TabNetClassifier(
        optimizer_fn=torch.optim.Adam,
        optimizer_params={"lr": 1e-3},
        device_name='cuda' if torch.cuda.is_available() else 'cpu',
        seed=42
    )

    tabnet_model.fit(
        X_train=X_train_np, y_train=y_train_np,
        eval_set=[(X_test_np, y_test_np)],
        eval_name=["val"],
        eval_metric=["accuracy", "logloss"],
        patience=n_patience,
        max_epochs=n_epochs,
        batch_size=1024,
        weights=sample_weights  # Menggunakan class weight per sample
    )



    # Melakukan evaluasi pada metrik accuracy, F1-score, dan precision
    preds = tabnet_model.predict(X_test_np)
    pred_proba = tabnet_model.predict_proba(X_test_np)

    acc = accuracy_score(y_test_np, preds)
    f1 = f1_score(y_test_np, preds, average='macro')
    precision = precision_score(y_test_np, preds, average='macro')
    logloss = min(tabnet_model.history['val_logloss']) # Menggunakan logloss terbaik dari proses fit


    # Menghitung multiclass AUC-ROC
    try:
        auc = roc_auc_score(y_test_np, pred_proba, multi_class='ovr', average='macro')
    except:
        auc = None

    try:
        fold_logloss_curve.append(tabnet_model.history['val_logloss'])
        fold_accuracy_curve.append(tabnet_model.history['val_accuracy'])
    except KeyError as e:
        print(f"KeyError: {e} tidak ditemukan dalam tabnet.history.")
        print("Available keys:", tabnet_model.history.keys())

    # Menyimpan model terbaik berdasarkan logloss
    if logloss < best_logloss:
        best_logloss = logloss
        best_model = tabnet_model
        best_fold = fold + 1
        best_preds = preds
        best_y_true = y_test_np

    print(f"Fold {fold+1} Metrics:")
    print(f"Accuracy: {acc:.4f}, F1: {f1:.4f}, Precision: {precision:.4f}, LogLoss: {logloss:.4f}, AUC: {auc:.4f}")

    # Menyimpan semua nilai metrik ke dictionary hasil
    fold_results['fold'].append(fold + 1)
    fold_results['accuracy'].append(acc)
    fold_results['f1_score'].append(f1)
    fold_results['precision'].append(precision)
    fold_results['roc_auc'].append(auc)
    fold_results['log_loss'].append(logloss)
# Out:
# Fold 1
# epoch 0  | loss: 2.51377 | val_accuracy: 0.14255 | val_logloss: 2.04992 |  0:00:01s
# epoch 1  | loss: 2.40686 | val_accuracy: 0.07451 | val_logloss: 2.1077  |  0:00:02s
# epoch 2  | loss: 2.34685 | val_accuracy: 0.07739 | val_logloss: 2.09884 |  0:00:02s
# epoch 3  | loss: 2.27112 | val_accuracy: 0.07235 | val_logloss: 2.072   |  0:00:03s
# epoch 4  | loss: 2.18795 | val_accuracy: 0.06983 | val_logloss: 2.07421 |  0:00:03s
# epoch 5  | loss: 2.16088 | val_accuracy: 0.07235 | val_logloss: 1.99262 |  0:00:04s
# epoch 6  | loss: 2.13193 | val_accuracy: 0.09287 | val_logloss: 1.96744 |  0:00:04s
# epoch 7  | loss: 2.08506 | val_accuracy: 0.10115 | val_logloss: 1.95644 |  0:00:05s
# epoch 8  | loss: 2.03416 | val_accuracy: 0.09539 | val_logloss: 1.9365  |  0:00:05s
# epoch 9  | loss: 1.97842 | val_accuracy: 0.14759 | val_logloss: 1.91961 |  0:00:06s
# epoch 10 | loss: 1.92363 | val_accuracy: 0.17675 | val_logloss: 1.90481 |  0:00:06s
# epoch 11 | loss: 1.93056 | val_accuracy: 0.24622 | val_logloss: 1.89571 |  0:00:07s
# epoch 12 | loss: 1.90036 | val_accuracy: 0.25414 | val_logloss: 1.87095 |  0:00:07s
# epoch 13 | loss: 1.86307 | val_accuracy: 0.3085  | val_logloss: 1.87154 |  0:00:08s
# epoch 14 | loss: 1.83355 | val_accuracy: 0.27646 | val_logloss: 1.83301 |  0:00:08s
# epoch 15 | loss: 1.80315 | val_accuracy: 0.32469 | val_logloss: 1.81431 |  0:00:09s
# epoch 16 | loss: 1.76446 | val_accuracy: 0.34233 | val_logloss: 1.81968 |  0:00:09s
# epoch 17 | loss: 1.73581 | val_accuracy: 0.32613 | val_logloss: 1.76166 |  0:00:10s
# epoch 18 | loss: 1.71025 | val_accuracy: 0.41397 | val_logloss: 1.73633 |  0:00:10s
# epoch 19 | loss: 1.6946  | val_accuracy: 0.43952 | val_logloss: 1.69735 |  0:00:11s
# epoch 20 | loss: 1.64809 | val_accuracy: 0.44024 | val_logloss: 1.68862 |  0:00:11s
# epoch 21 | loss: 1.62715 | val_accuracy: 0.45248 | val_logloss: 1.678   |  0:00:12s
# epoch 22 | loss: 1.60937 | val_accuracy: 0.53096 | val_logloss: 1.62747 |  0:00:12s
# epoch 23 | loss: 1.60124 | val_accuracy: 0.53348 | val_logloss: 1.59576 |  0:00:13s
# epoch 24 | loss: 1.54593 | val_accuracy: 0.48992 | val_logloss: 1.58829 |  0:00:13s
# epoch 25 | loss: 1.5361  | val_accuracy: 0.4766  | val_logloss: 1.54271 |  0:00:14s
# epoch 26 | loss: 1.50688 | val_accuracy: 0.5558  | val_logloss: 1.51617 |  0:00:14s
# epoch 27 | loss: 1.4921  | val_accuracy: 0.5342  | val_logloss: 1.47726 |  0:00:15s
# epoch 28 | loss: 1.47644 | val_accuracy: 0.53276 | val_logloss: 1.43844 |  0:00:15s
# epoch 29 | loss: 1.41101 | val_accuracy: 0.60295 | val_logloss: 1.36323 |  0:00:15s
# epoch 30 | loss: 1.36099 | val_accuracy: 0.63967 | val_logloss: 1.28753 |  0:00:16s
# epoch 31 | loss: 1.34626 | val_accuracy: 0.65155 | val_logloss: 1.2527  |  0:00:16s
# epoch 32 | loss: 1.33878 | val_accuracy: 0.65551 | val_logloss: 1.23854 |  0:00:17s
# epoch 33 | loss: 1.28842 | val_accuracy: 0.66487 | val_logloss: 1.20069 |  0:00:17s
# epoch 34 | loss: 1.23245 | val_accuracy: 0.67747 | val_logloss: 1.14347 |  0:00:18s
# epoch 35 | loss: 1.1963  | val_accuracy: 0.68754 | val_logloss: 1.09148 |  0:00:18s
# epoch 36 | loss: 1.17074 | val_accuracy: 0.69474 | val_logloss: 1.08041 |  0:00:19s
# epoch 37 | loss: 1.1619  | val_accuracy: 0.69618 | val_logloss: 1.03552 |  0:00:19s
# epoch 38 | loss: 1.11101 | val_accuracy: 0.69942 | val_logloss: 0.97038 |  0:00:20s
# epoch 39 | loss: 1.04325 | val_accuracy: 0.69834 | val_logloss: 0.97247 |  0:00:20s
# epoch 40 | loss: 1.0359  | val_accuracy: 0.6951  | val_logloss: 0.98071 |  0:00:21s
# epoch 41 | loss: 0.97979 | val_accuracy: 0.69294 | val_logloss: 0.97722 |  0:00:21s
# epoch 42 | loss: 0.92521 | val_accuracy: 0.69618 | val_logloss: 0.91682 |  0:00:22s
# epoch 43 | loss: 0.90239 | val_accuracy: 0.73542 | val_logloss: 0.89841 |  0:00:22s
# epoch 44 | loss: 0.81899 | val_accuracy: 0.73074 | val_logloss: 0.8644  |  0:00:23s
# epoch 45 | loss: 0.78272 | val_accuracy: 0.72642 | val_logloss: 0.80815 |  0:00:23s
# epoch 46 | loss: 0.75346 | val_accuracy: 0.73038 | val_logloss: 0.79824 |  0:00:24s
# epoch 47 | loss: 0.69153 | val_accuracy: 0.73218 | val_logloss: 0.74245 |  0:00:24s
# epoch 48 | loss: 0.66669 | val_accuracy: 0.7275  | val_logloss: 0.73371 |  0:00:25s
# epoch 49 | loss: 0.61065 | val_accuracy: 0.72858 | val_logloss: 0.70075 |  0:00:25s
# Stop training because you reached max_epochs = 50 with best_epoch = 49 and best_val_logloss = 0.70075
# Fold 1 Metrics:
# Accuracy: 0.7286, F1: 0.7347, Precision: 0.7440, LogLoss: 0.7008, AUC: 0.9562
#
# Fold 2
# epoch 0  | loss: 2.53317 | val_accuracy: 0.14476 | val_logloss: 2.05772 |  0:00:00s
# epoch 1  | loss: 2.40032 | val_accuracy: 0.10479 | val_logloss: 2.11785 |  0:00:00s
# epoch 2  | loss: 2.31979 | val_accuracy: 0.07562 | val_logloss: 2.11788 |  0:00:01s
# epoch 3  | loss: 2.23852 | val_accuracy: 0.07598 | val_logloss: 2.14182 |  0:00:01s
# epoch 4  | loss: 2.20659 | val_accuracy: 0.07382 | val_logloss: 2.04052 |  0:00:02s
# epoch 5  | loss: 2.1354  | val_accuracy: 0.09183 | val_logloss: 2.03458 |  0:00:02s
# epoch 6  | loss: 2.06616 | val_accuracy: 0.07058 | val_logloss: 2.03823 |  0:00:03s
# epoch 7  | loss: 2.06072 | val_accuracy: 0.08894 | val_logloss: 2.02599 |  0:00:03s
# epoch 8  | loss: 1.98358 | val_accuracy: 0.07562 | val_logloss: 2.03491 |  0:00:04s
# epoch 9  | loss: 1.97073 | val_accuracy: 0.11271 | val_logloss: 2.03013 |  0:00:04s
# epoch 10 | loss: 1.92929 | val_accuracy: 0.18833 | val_logloss: 1.94805 |  0:00:05s
# epoch 11 | loss: 1.90346 | val_accuracy: 0.20526 | val_logloss: 1.93453 |  0:00:05s
# epoch 12 | loss: 1.8755  | val_accuracy: 0.15988 | val_logloss: 1.92995 |  0:00:06s
# epoch 13 | loss: 1.84396 | val_accuracy: 0.18257 | val_logloss: 1.90327 |  0:00:06s
# epoch 14 | loss: 1.84571 | val_accuracy: 0.16385 | val_logloss: 1.9172  |  0:00:07s
# epoch 15 | loss: 1.80402 | val_accuracy: 0.16817 | val_logloss: 1.90023 |  0:00:07s
# epoch 16 | loss: 1.78068 | val_accuracy: 0.17609 | val_logloss: 1.86736 |  0:00:08s
# epoch 17 | loss: 1.74011 | val_accuracy: 0.16673 | val_logloss: 1.83381 |  0:00:08s
# epoch 18 | loss: 1.73488 | val_accuracy: 0.17717 | val_logloss: 1.77957 |  0:00:09s
# epoch 19 | loss: 1.71419 | val_accuracy: 0.22002 | val_logloss: 1.76055 |  0:00:09s
# epoch 20 | loss: 1.7023  | val_accuracy: 0.25495 | val_logloss: 1.76185 |  0:00:10s
# epoch 21 | loss: 1.66129 | val_accuracy: 0.26287 | val_logloss: 1.73052 |  0:00:10s
# epoch 22 | loss: 1.63037 | val_accuracy: 0.26972 | val_logloss: 1.69837 |  0:00:11s
# epoch 23 | loss: 1.58147 | val_accuracy: 0.2978  | val_logloss: 1.66244 |  0:00:11s
# epoch 24 | loss: 1.5602  | val_accuracy: 0.33021 | val_logloss: 1.64531 |  0:00:12s
# epoch 25 | loss: 1.51426 | val_accuracy: 0.36874 | val_logloss: 1.60598 |  0:00:12s
# epoch 26 | loss: 1.51466 | val_accuracy: 0.36802 | val_logloss: 1.5542  |  0:00:13s
# epoch 27 | loss: 1.4678  | val_accuracy: 0.47929 | val_logloss: 1.48916 |  0:00:13s
# epoch 28 | loss: 1.41713 | val_accuracy: 0.50486 | val_logloss: 1.47828 |  0:00:14s
# epoch 29 | loss: 1.3785  | val_accuracy: 0.5153  | val_logloss: 1.42511 |  0:00:14s
# epoch 30 | loss: 1.33782 | val_accuracy: 0.53511 | val_logloss: 1.38644 |  0:00:15s
# epoch 31 | loss: 1.29415 | val_accuracy: 0.55023 | val_logloss: 1.29984 |  0:00:16s
# epoch 32 | loss: 1.24734 | val_accuracy: 0.59129 | val_logloss: 1.26714 |  0:00:16s
# epoch 33 | loss: 1.21464 | val_accuracy: 0.56356 | val_logloss: 1.24698 |  0:00:17s
# epoch 34 | loss: 1.13866 | val_accuracy: 0.74397 | val_logloss: 1.18127 |  0:00:17s
# epoch 35 | loss: 1.11501 | val_accuracy: 0.66151 | val_logloss: 1.14055 |  0:00:18s
# epoch 36 | loss: 1.06262 | val_accuracy: 0.75117 | val_logloss: 1.11711 |  0:00:18s
# epoch 37 | loss: 1.01993 | val_accuracy: 0.75945 | val_logloss: 1.04745 |  0:00:18s
# epoch 38 | loss: 0.96023 | val_accuracy: 0.76882 | val_logloss: 1.00725 |  0:00:19s
# epoch 39 | loss: 0.91029 | val_accuracy: 0.77782 | val_logloss: 0.93881 |  0:00:19s
# epoch 40 | loss: 0.90304 | val_accuracy: 0.75153 | val_logloss: 0.94756 |  0:00:20s
# epoch 41 | loss: 0.84457 | val_accuracy: 0.70544 | val_logloss: 0.8462  |  0:00:20s
# epoch 42 | loss: 0.78906 | val_accuracy: 0.72056 | val_logloss: 0.80936 |  0:00:21s
# epoch 43 | loss: 0.73906 | val_accuracy: 0.89701 | val_logloss: 0.74638 |  0:00:21s
# epoch 44 | loss: 0.70862 | val_accuracy: 0.86352 | val_logloss: 0.72111 |  0:00:22s
# epoch 45 | loss: 0.68838 | val_accuracy: 0.75189 | val_logloss: 0.69155 |  0:00:22s
# epoch 46 | loss: 0.64131 | val_accuracy: 0.89413 | val_logloss: 0.64174 |  0:00:23s
# epoch 47 | loss: 0.5919  | val_accuracy: 0.87577 | val_logloss: 0.57538 |  0:00:23s
# epoch 48 | loss: 0.55677 | val_accuracy: 0.89665 | val_logloss: 0.54374 |  0:00:24s
# epoch 49 | loss: 0.52388 | val_accuracy: 0.90853 | val_logloss: 0.46602 |  0:00:24s
# Stop training because you reached max_epochs = 50 with best_epoch = 49 and best_val_logloss = 0.46602
# Fold 2 Metrics:
# Accuracy: 0.9085, F1: 0.8810, Precision: 0.8634, LogLoss: 0.4660, AUC: 0.9842
#
# Fold 3
# epoch 0  | loss: 2.5485  | val_accuracy: 0.14332 | val_logloss: 2.03181 |  0:00:00s
# epoch 1  | loss: 2.46614 | val_accuracy: 0.08354 | val_logloss: 2.12617 |  0:00:00s
# epoch 2  | loss: 2.35113 | val_accuracy: 0.07418 | val_logloss: 2.13009 |  0:00:01s
# epoch 3  | loss: 2.25632 | val_accuracy: 0.07922 | val_logloss: 2.10954 |  0:00:01s
# epoch 4  | loss: 2.22269 | val_accuracy: 0.07418 | val_logloss: 2.10085 |  0:00:02s
# epoch 5  | loss: 2.17231 | val_accuracy: 0.08318 | val_logloss: 2.12929 |  0:00:02s
# epoch 6  | loss: 2.13079 | val_accuracy: 0.07778 | val_logloss: 2.11104 |  0:00:03s
# epoch 7  | loss: 2.02151 | val_accuracy: 0.08606 | val_logloss: 2.04492 |  0:00:03s
# epoch 8  | loss: 1.99148 | val_accuracy: 0.09903 | val_logloss: 2.0171  |  0:00:04s
# epoch 9  | loss: 1.96042 | val_accuracy: 0.16745 | val_logloss: 1.99457 |  0:00:04s
# epoch 10 | loss: 1.948   | val_accuracy: 0.12351 | val_logloss: 1.93032 |  0:00:05s
# epoch 11 | loss: 1.9079  | val_accuracy: 0.1282  | val_logloss: 1.90393 |  0:00:05s
# epoch 12 | loss: 1.86052 | val_accuracy: 0.14476 | val_logloss: 1.89064 |  0:00:06s
# epoch 13 | loss: 1.86316 | val_accuracy: 0.2211  | val_logloss: 1.87475 |  0:00:06s
# epoch 14 | loss: 1.80625 | val_accuracy: 0.22686 | val_logloss: 1.86142 |  0:00:07s
# epoch 15 | loss: 1.79834 | val_accuracy: 0.25891 | val_logloss: 1.81872 |  0:00:07s
# epoch 16 | loss: 1.74969 | val_accuracy: 0.28484 | val_logloss: 1.85054 |  0:00:08s
# epoch 17 | loss: 1.73834 | val_accuracy: 0.24055 | val_logloss: 1.8064  |  0:00:08s
# epoch 18 | loss: 1.7013  | val_accuracy: 0.33813 | val_logloss: 1.74674 |  0:00:09s
# epoch 19 | loss: 1.70419 | val_accuracy: 0.4116  | val_logloss: 1.73122 |  0:00:09s
# epoch 20 | loss: 1.65398 | val_accuracy: 0.43464 | val_logloss: 1.69403 |  0:00:10s
# epoch 21 | loss: 1.61278 | val_accuracy: 0.49838 | val_logloss: 1.65933 |  0:00:10s
# epoch 22 | loss: 1.60349 | val_accuracy: 0.48758 | val_logloss: 1.63423 |  0:00:11s
# epoch 23 | loss: 1.56294 | val_accuracy: 0.556   | val_logloss: 1.55178 |  0:00:11s
# epoch 24 | loss: 1.54314 | val_accuracy: 0.60353 | val_logloss: 1.52019 |  0:00:12s
# epoch 25 | loss: 1.48701 | val_accuracy: 0.60029 | val_logloss: 1.51867 |  0:00:12s
# epoch 26 | loss: 1.46979 | val_accuracy: 0.59741 | val_logloss: 1.494   |  0:00:13s
# epoch 27 | loss: 1.46972 | val_accuracy: 0.59705 | val_logloss: 1.43105 |  0:00:13s
# epoch 28 | loss: 1.41479 | val_accuracy: 0.59885 | val_logloss: 1.37339 |  0:00:14s
# epoch 29 | loss: 1.37893 | val_accuracy: 0.66223 | val_logloss: 1.30845 |  0:00:14s
# epoch 30 | loss: 1.36132 | val_accuracy: 0.66187 | val_logloss: 1.23839 |  0:00:15s
# epoch 31 | loss: 1.31195 | val_accuracy: 0.66583 | val_logloss: 1.19335 |  0:00:15s
# epoch 32 | loss: 1.2785  | val_accuracy: 0.6543  | val_logloss: 1.18792 |  0:00:16s
# epoch 33 | loss: 1.22865 | val_accuracy: 0.73172 | val_logloss: 1.14421 |  0:00:16s
# epoch 34 | loss: 1.17563 | val_accuracy: 0.73749 | val_logloss: 1.1178  |  0:00:17s
# epoch 35 | loss: 1.13136 | val_accuracy: 0.68275 | val_logloss: 1.07143 |  0:00:17s
# epoch 36 | loss: 1.13903 | val_accuracy: 0.62441 | val_logloss: 1.04043 |  0:00:18s
# epoch 37 | loss: 1.09578 | val_accuracy: 0.62766 | val_logloss: 1.03991 |  0:00:18s
# epoch 38 | loss: 1.04621 | val_accuracy: 0.63594 | val_logloss: 0.97958 |  0:00:19s
# epoch 39 | loss: 1.00565 | val_accuracy: 0.61577 | val_logloss: 0.9644  |  0:00:19s
# epoch 40 | loss: 0.94253 | val_accuracy: 0.62982 | val_logloss: 0.91815 |  0:00:20s
# epoch 41 | loss: 0.92864 | val_accuracy: 0.64026 | val_logloss: 0.89956 |  0:00:20s
# epoch 42 | loss: 0.90182 | val_accuracy: 0.66871 | val_logloss: 0.85988 |  0:00:21s
# epoch 43 | loss: 0.86147 | val_accuracy: 0.65538 | val_logloss: 0.84792 |  0:00:21s
# epoch 44 | loss: 0.80318 | val_accuracy: 0.67591 | val_logloss: 0.82603 |  0:00:22s
# epoch 45 | loss: 0.78449 | val_accuracy: 0.67771 | val_logloss: 0.79555 |  0:00:22s
# epoch 46 | loss: 0.77757 | val_accuracy: 0.66151 | val_logloss: 0.80917 |  0:00:23s
# epoch 47 | loss: 0.73564 | val_accuracy: 0.68491 | val_logloss: 0.76851 |  0:00:23s
# epoch 48 | loss: 0.70101 | val_accuracy: 0.68455 | val_logloss: 0.75479 |  0:00:23s
# epoch 49 | loss: 0.68462 | val_accuracy: 0.70436 | val_logloss: 0.73548 |  0:00:24s
# Stop training because you reached max_epochs = 50 with best_epoch = 49 and best_val_logloss = 0.73548
# Fold 3 Metrics:
# Accuracy: 0.7044, F1: 0.7447, Precision: 0.7498, LogLoss: 0.7355, AUC: 0.9718
#
# Fold 4
# epoch 0  | loss: 2.55036 | val_accuracy: 0.1444  | val_logloss: 1.99012 |  0:00:00s
# epoch 1  | loss: 2.45004 | val_accuracy: 0.09759 | val_logloss: 2.0335  |  0:00:01s
# epoch 2  | loss: 2.36514 | val_accuracy: 0.07778 | val_logloss: 2.05496 |  0:00:01s
# epoch 3  | loss: 2.27904 | val_accuracy: 0.07922 | val_logloss: 2.04879 |  0:00:02s
# epoch 4  | loss: 2.22526 | val_accuracy: 0.09831 | val_logloss: 2.0566  |  0:00:02s
# epoch 5  | loss: 2.17078 | val_accuracy: 0.06878 | val_logloss: 2.06377 |  0:00:02s
# epoch 6  | loss: 2.09388 | val_accuracy: 0.05798 | val_logloss: 2.08211 |  0:00:03s
# epoch 7  | loss: 2.07421 | val_accuracy: 0.10335 | val_logloss: 2.02286 |  0:00:03s
# epoch 8  | loss: 2.03983 | val_accuracy: 0.15484 | val_logloss: 2.04231 |  0:00:04s
# epoch 9  | loss: 2.01632 | val_accuracy: 0.17357 | val_logloss: 2.02504 |  0:00:04s
# epoch 10 | loss: 1.94111 | val_accuracy: 0.20202 | val_logloss: 2.00631 |  0:00:05s
# epoch 11 | loss: 1.92398 | val_accuracy: 0.19229 | val_logloss: 1.97458 |  0:00:05s
# epoch 12 | loss: 1.91521 | val_accuracy: 0.2301  | val_logloss: 1.92094 |  0:00:06s
# epoch 13 | loss: 1.89413 | val_accuracy: 0.23263 | val_logloss: 1.89998 |  0:00:06s
# epoch 14 | loss: 1.84997 | val_accuracy: 0.21102 | val_logloss: 1.88343 |  0:00:07s
# epoch 15 | loss: 1.83219 | val_accuracy: 0.21714 | val_logloss: 1.87964 |  0:00:07s
# epoch 16 | loss: 1.79097 | val_accuracy: 0.2319  | val_logloss: 1.85992 |  0:00:08s
# epoch 17 | loss: 1.75516 | val_accuracy: 0.22146 | val_logloss: 1.84953 |  0:00:08s
# epoch 18 | loss: 1.77328 | val_accuracy: 0.21138 | val_logloss: 1.85663 |  0:00:09s
# epoch 19 | loss: 1.7365  | val_accuracy: 0.23046 | val_logloss: 1.78618 |  0:00:09s
# epoch 20 | loss: 1.71729 | val_accuracy: 0.23947 | val_logloss: 1.75849 |  0:00:10s
# epoch 21 | loss: 1.66818 | val_accuracy: 0.26792 | val_logloss: 1.73886 |  0:00:10s
# epoch 22 | loss: 1.66483 | val_accuracy: 0.24847 | val_logloss: 1.74365 |  0:00:11s
# epoch 23 | loss: 1.61731 | val_accuracy: 0.29204 | val_logloss: 1.68551 |  0:00:11s
# epoch 24 | loss: 1.60232 | val_accuracy: 0.26936 | val_logloss: 1.71094 |  0:00:12s
# epoch 25 | loss: 1.586   | val_accuracy: 0.32193 | val_logloss: 1.6569  |  0:00:12s
# epoch 26 | loss: 1.54543 | val_accuracy: 0.39503 | val_logloss: 1.61659 |  0:00:13s
# epoch 27 | loss: 1.52005 | val_accuracy: 0.38495 | val_logloss: 1.59106 |  0:00:13s
# epoch 28 | loss: 1.48959 | val_accuracy: 0.43572 | val_logloss: 1.54376 |  0:00:14s
# epoch 29 | loss: 1.46874 | val_accuracy: 0.49262 | val_logloss: 1.46281 |  0:00:14s
# epoch 30 | loss: 1.45054 | val_accuracy: 0.52287 | val_logloss: 1.45351 |  0:00:15s
# epoch 31 | loss: 1.39389 | val_accuracy: 0.52719 | val_logloss: 1.38884 |  0:00:15s
# epoch 32 | loss: 1.36086 | val_accuracy: 0.51855 | val_logloss: 1.35188 |  0:00:16s
# epoch 33 | loss: 1.3366  | val_accuracy: 0.51314 | val_logloss: 1.29874 |  0:00:16s
# epoch 34 | loss: 1.28852 | val_accuracy: 0.52323 | val_logloss: 1.28769 |  0:00:17s
# epoch 35 | loss: 1.26236 | val_accuracy: 0.54951 | val_logloss: 1.23472 |  0:00:17s
# epoch 36 | loss: 1.23061 | val_accuracy: 0.53475 | val_logloss: 1.2159  |  0:00:18s
# epoch 37 | loss: 1.19427 | val_accuracy: 0.55059 | val_logloss: 1.13408 |  0:00:18s
# epoch 38 | loss: 1.20364 | val_accuracy: 0.56464 | val_logloss: 1.13145 |  0:00:19s
# epoch 39 | loss: 1.14045 | val_accuracy: 0.56176 | val_logloss: 1.12985 |  0:00:19s
# epoch 40 | loss: 1.12936 | val_accuracy: 0.56824 | val_logloss: 1.09902 |  0:00:20s
# epoch 41 | loss: 1.07673 | val_accuracy: 0.54267 | val_logloss: 1.03948 |  0:00:20s
# epoch 42 | loss: 1.05384 | val_accuracy: 0.55996 | val_logloss: 1.04914 |  0:00:21s
# epoch 43 | loss: 1.02882 | val_accuracy: 0.63342 | val_logloss: 1.0311  |  0:00:21s
# epoch 44 | loss: 0.97942 | val_accuracy: 0.63522 | val_logloss: 0.98717 |  0:00:22s
# epoch 45 | loss: 0.94109 | val_accuracy: 0.6399  | val_logloss: 0.94971 |  0:00:22s
# epoch 46 | loss: 0.92016 | val_accuracy: 0.65394 | val_logloss: 0.92174 |  0:00:23s
# epoch 47 | loss: 0.8855  | val_accuracy: 0.65286 | val_logloss: 0.91089 |  0:00:23s
# epoch 48 | loss: 0.84008 | val_accuracy: 0.65322 | val_logloss: 0.88861 |  0:00:24s
# epoch 49 | loss: 0.83057 | val_accuracy: 0.66079 | val_logloss: 0.85555 |  0:00:24s
# Stop training because you reached max_epochs = 50 with best_epoch = 49 and best_val_logloss = 0.85555
# Fold 4 Metrics:
# Accuracy: 0.6608, F1: 0.6632, Precision: 0.6936, LogLoss: 0.8556, AUC: 0.9347
#
# Fold 5
# epoch 0  | loss: 2.53771 | val_accuracy: 0.14476 | val_logloss: 2.02565 |  0:00:00s
# epoch 1  | loss: 2.46298 | val_accuracy: 0.12928 | val_logloss: 2.08159 |  0:00:00s
# epoch 2  | loss: 2.34785 | val_accuracy: 0.0695  | val_logloss: 2.10518 |  0:00:01s
# epoch 3  | loss: 2.29013 | val_accuracy: 0.07778 | val_logloss: 2.09227 |  0:00:01s
# epoch 4  | loss: 2.20709 | val_accuracy: 0.07166 | val_logloss: 2.06175 |  0:00:02s
# epoch 5  | loss: 2.17005 | val_accuracy: 0.07994 | val_logloss: 2.02496 |  0:00:02s
# epoch 6  | loss: 2.07971 | val_accuracy: 0.08786 | val_logloss: 2.04518 |  0:00:03s
# epoch 7  | loss: 2.03469 | val_accuracy: 0.10047 | val_logloss: 1.99254 |  0:00:03s
# epoch 8  | loss: 2.00486 | val_accuracy: 0.11415 | val_logloss: 2.00221 |  0:00:04s
# epoch 9  | loss: 1.99659 | val_accuracy: 0.21066 | val_logloss: 1.98291 |  0:00:04s
# epoch 10 | loss: 1.969   | val_accuracy: 0.11703 | val_logloss: 1.95058 |  0:00:05s
# epoch 11 | loss: 1.91013 | val_accuracy: 0.24235 | val_logloss: 1.94499 |  0:00:05s
# epoch 12 | loss: 1.89244 | val_accuracy: 0.19121 | val_logloss: 1.90441 |  0:00:06s
# epoch 13 | loss: 1.86699 | val_accuracy: 0.26467 | val_logloss: 1.92344 |  0:00:06s
# epoch 14 | loss: 1.83827 | val_accuracy: 0.24415 | val_logloss: 1.91303 |  0:00:07s
# epoch 15 | loss: 1.81553 | val_accuracy: 0.26107 | val_logloss: 1.91725 |  0:00:07s
# epoch 16 | loss: 1.78383 | val_accuracy: 0.36298 | val_logloss: 1.95172 |  0:00:08s
# epoch 17 | loss: 1.76501 | val_accuracy: 0.32157 | val_logloss: 1.89732 |  0:00:08s
# epoch 18 | loss: 1.74467 | val_accuracy: 0.34066 | val_logloss: 1.85456 |  0:00:09s
# epoch 19 | loss: 1.71153 | val_accuracy: 0.25999 | val_logloss: 1.83501 |  0:00:09s
# epoch 20 | loss: 1.6784  | val_accuracy: 0.38459 | val_logloss: 1.74253 |  0:00:10s
# epoch 21 | loss: 1.62715 | val_accuracy: 0.41232 | val_logloss: 1.70098 |  0:00:10s
# epoch 22 | loss: 1.58063 | val_accuracy: 0.4883  | val_logloss: 1.65922 |  0:00:11s
# epoch 23 | loss: 1.56426 | val_accuracy: 0.55744 | val_logloss: 1.63746 |  0:00:11s
# epoch 24 | loss: 1.55206 | val_accuracy: 0.54411 | val_logloss: 1.59472 |  0:00:12s
# epoch 25 | loss: 1.48057 | val_accuracy: 0.53187 | val_logloss: 1.50296 |  0:00:12s
# epoch 26 | loss: 1.4468  | val_accuracy: 0.54807 | val_logloss: 1.51346 |  0:00:13s
# epoch 27 | loss: 1.403   | val_accuracy: 0.48902 | val_logloss: 1.46035 |  0:00:13s
# epoch 28 | loss: 1.35043 | val_accuracy: 0.4973  | val_logloss: 1.36408 |  0:00:14s
# epoch 29 | loss: 1.31577 | val_accuracy: 0.48722 | val_logloss: 1.33674 |  0:00:14s
# epoch 30 | loss: 1.27182 | val_accuracy: 0.5099  | val_logloss: 1.27126 |  0:00:15s
# epoch 31 | loss: 1.23861 | val_accuracy: 0.53259 | val_logloss: 1.20484 |  0:00:15s
# epoch 32 | loss: 1.18766 | val_accuracy: 0.59021 | val_logloss: 1.17626 |  0:00:16s
# epoch 33 | loss: 1.16478 | val_accuracy: 0.56392 | val_logloss: 1.15787 |  0:00:16s
# epoch 34 | loss: 1.11487 | val_accuracy: 0.65898 | val_logloss: 1.09062 |  0:00:17s
# epoch 35 | loss: 1.0682  | val_accuracy: 0.63774 | val_logloss: 1.05263 |  0:00:17s
# epoch 36 | loss: 1.01255 | val_accuracy: 0.60785 | val_logloss: 1.03974 |  0:00:18s
# epoch 37 | loss: 0.99503 | val_accuracy: 0.64926 | val_logloss: 1.03688 |  0:00:18s
# epoch 38 | loss: 0.98818 | val_accuracy: 0.69716 | val_logloss: 1.01261 |  0:00:19s
# epoch 39 | loss: 0.95489 | val_accuracy: 0.70688 | val_logloss: 0.9666  |  0:00:19s
# epoch 40 | loss: 0.89896 | val_accuracy: 0.72416 | val_logloss: 0.95419 |  0:00:20s
# epoch 41 | loss: 0.88249 | val_accuracy: 0.7274  | val_logloss: 0.88114 |  0:00:20s
# epoch 42 | loss: 0.8556  | val_accuracy: 0.73749 | val_logloss: 0.86206 |  0:00:21s
# epoch 43 | loss: 0.79937 | val_accuracy: 0.74613 | val_logloss: 0.82354 |  0:00:21s
# epoch 44 | loss: 0.78305 | val_accuracy: 0.74541 | val_logloss: 0.83605 |  0:00:22s
# epoch 45 | loss: 0.71865 | val_accuracy: 0.74253 | val_logloss: 0.79026 |  0:00:22s
# epoch 46 | loss: 0.69638 | val_accuracy: 0.74361 | val_logloss: 0.78098 |  0:00:23s
# epoch 47 | loss: 0.67728 | val_accuracy: 0.74865 | val_logloss: 0.71849 |  0:00:23s
# epoch 48 | loss: 0.62113 | val_accuracy: 0.75765 | val_logloss: 0.69806 |  0:00:24s
# epoch 49 | loss: 0.57692 | val_accuracy: 0.75765 | val_logloss: 0.67806 |  0:00:24s
# Stop training because you reached max_epochs = 50 with best_epoch = 49 and best_val_logloss = 0.67806
# Fold 5 Metrics:
# Accuracy: 0.7577, F1: 0.7612, Precision: 0.7572, LogLoss: 0.6781, AUC: 0.9740

# %%
# Menyimpan model terbaik pada database
if best_model is not None:
    if n_epochs == 100 and n_patience == 15:
        best_model_path = f"/content/drive/MyDrive/Model_Skripsi/TabNet/epoch_100/RT-IoT-2022_tabnet__best_model_fold{best_fold}_logloss{best_logloss:.6f}"
    elif n_epochs == 50 and n_patience == 15:
        best_model_path = f"/content/drive/MyDrive/Model_Skripsi/TabNet/epoch_50/RT-IoT-2022_tabnet_best_model_fold{best_fold}_logloss{best_logloss:.6f}"


    best_model.save_model(best_model_path)
    print(f"Model terbaik disimpan dari Fold {best_fold} dengan logloss: {best_logloss:.6f}")
# Out:
# Successfully saved model at /content/drive/MyDrive/Model_Skripsi/TabNet/epoch_50/RT-IoT-2022_tabnet_best_model_fold2_logloss0.466018.zip
# Model terbaik disimpan dari Fold 2 dengan logloss: 0.466018

# %%
# Menampilkan visualisasi kurva logloss per epoch pada setiap fold
functions.plot_curve(fold_logloss_curve, metric_name="Validation LogLoss")

# %%
# Menampilkan visualisasi kurva accuracy per epoch pada setiap fold
functions.plot_curve(fold_accuracy_curve, metric_name="Validation Accuracy")

# %%
# Menampilkan rata-rata semua metrik dari semua fold
print("\nRata-Rata Hasil Cross Validation:")
for metric in ['accuracy', 'f1_score', 'precision', 'roc_auc', 'log_loss']:
    avg_value = np.mean([val for val in fold_results[metric] if val is not None])
    print(f"{metric}: {avg_value:.4f}")
# Out:
# Rata-Rata Hasil Cross Validation:
# accuracy: 0.7520
# f1_score: 0.7570
# precision: 0.7616
# roc_auc: 0.9642
# log_loss: 0.6872

# %%
# Menampilkan visualisasi keakuratan prediksi model
functions.plot_best_confusion_matrix(best_y_true, best_preds, best_fold)
