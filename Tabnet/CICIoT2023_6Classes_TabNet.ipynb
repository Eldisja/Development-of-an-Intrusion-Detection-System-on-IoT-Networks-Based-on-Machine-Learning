# %%
# !pip install -q pytorch-tabular

# %%
# Menambahkan path direktori Kode_Skripsi untuk mengimpor file functions.py
import sys
sys.path.append('/content/drive/MyDrive/Kode_Skripsi')

# %%
# !cp /content/drive/MyDrive/Kode_Skripsi/functions.py /content/

# %% [markdown]
# #Pre-processing

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import f1_score, precision_score, roc_auc_score,log_loss, accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.utils.class_weight import compute_class_weight

import torch
import os
import functions

# %%
# Mengabaikan warning penggunaan processor dan konfigurasi penggunaan weight terbaik dari epoch sebelumnya
functions.ignore_warnings()

# %%
# Mengambil dataset CIC IoT 2023
ciciot2023__6classes = '/content/drive/MyDrive/Dataset_Skripsi/6_Classes/CIC_IOT_2023_6Classes.csv'

df = pd.read_csv(ciciot2023__6classes)

# Memisahkan kolom fitur dan target
X = df.drop(columns=['Label'])
y = df['Label']

# %%
# Menyimpan label asli sebelum encoding agar tidak ikut termodifikasi
y_label = y.copy()

# Melakukan encoding label utama (y) sekali untuk StratifiedKFold
y_encoded = LabelEncoder().fit_transform(y.squeeze())

# %%
# Menampilkan hasil encoding
functions.show_label_encoding(y, y_encoded)
# Out:
# ===== Mapping Label Encoding (Attack_type) =====
#         Label_Original  Label_Encoded
# DDOS-ACK_FRAGMENTATION              0
# DDOS-UDP_FRAGMENTATION              1
#           DNS_SPOOFING              2
#         DOS-HTTP_FLOOD              3
#    RECON-HOSTDISCOVERY              4
#      VULNERABILITYSCAN              5

# %% [markdown]
# ##Tabnet

# %%
# Melakukan Stratified K-Fold dengan 5 fold dan hasilnya diacak
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Memastikan folder Model_Skripsi tersedia
os.makedirs("/content/drive/MyDrive/Model_Skripsi/", exist_ok=True)

# %%
# Melakukan inisialisasi untuk menyimpan kurva metrik per epoch dalam setiap fold
fold_logloss_curve = []
fold_accuracy_curve = []

# Melakukan inisialisasi untuk nantinya menyimpan metrik setiap fold
fold_results = {
    'fold': [],
    'accuracy': [],
    'f1_score': [],
    'precision': [],
    'roc_auc': [],
    'log_loss': []
}

# Melakukan inisialisasi model terbaik
best_model_path = ""

best_logloss = float('inf')
best_y_true = None
best_preds = None

# Melakukan inisialisasi untuk nilai epoch dan patience yang sedang digunakan
n_epochs = 50
n_patience = 15

# Melakukan Cross-validation
for fold, (train_idx, test_idx) in enumerate(skf.split(X, y_encoded)):
    print(f"\nFold {fold+1}")

    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    # Melakukan encoding dan scaling
    X_train_np, X_test_np, y_train_np, y_test_np = functions.encoding_cic_iot_2023_7classes(X_train, X_test, y_train, y_test)

    # Menggunakan compute class weights untuk bobot balancing dataset
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_np),
        y=y_train_np
    )
    sample_weights = class_weights[y_train_np]  # bobot per sampel

    # Melakukan training TabNet
    tabnet_model = TabNetClassifier(
        optimizer_fn=torch.optim.Adam,
        optimizer_params={"lr": 1e-3},
        device_name='cuda' if torch.cuda.is_available() else 'cpu',
        seed=42
    )

    tabnet_model.fit(
        X_train=X_train_np, y_train=y_train_np,
        eval_set=[(X_test_np, y_test_np)],
        eval_name=["val"],
        eval_metric=["accuracy", "logloss"],
        patience=n_patience,
        max_epochs=n_epochs,
        batch_size=1024,
        weights=sample_weights  # Menggunakan class weight per sample
    )



    # Melakukan evaluasi pada metrik accuracy, F1-score, dan precision
    preds = tabnet_model.predict(X_test_np)
    pred_proba = tabnet_model.predict_proba(X_test_np)

    acc = accuracy_score(y_test_np, preds)
    f1 = f1_score(y_test_np, preds, average='macro')
    precision = precision_score(y_test_np, preds, average='macro')
    logloss = min(tabnet_model.history['val_logloss']) # Menggunakan logloss terbaik dari proses fit


    # Menghitung multiclass AUC-ROC
    try:
        auc = roc_auc_score(y_test_np, pred_proba, multi_class='ovr', average='macro')
    except:
        auc = None

    try:
        fold_logloss_curve.append(tabnet_model.history['val_logloss'])
        fold_accuracy_curve.append(tabnet_model.history['val_accuracy'])
    except KeyError as e:
        print(f"KeyError: {e} tidak ditemukan dalam tabnet.history.")
        print("Available keys:", tabnet_model.history.keys())

    # Menyimpan model terbaik berdasarkan logloss
    if logloss < best_logloss:
        best_logloss = logloss
        best_model = tabnet_model
        best_fold = fold + 1
        best_preds = preds
        best_y_true = y_test_np

    print(f"Fold {fold+1} Metrics:")
    print(f"Accuracy: {acc:.4f}, F1: {f1:.4f}, Precision: {precision:.4f}, LogLoss: {logloss:.4f}, AUC: {auc:.4f}")

    # Menyimpan semua nilai metrik ke dictionary hasil
    fold_results['fold'].append(fold + 1)
    fold_results['accuracy'].append(acc)
    fold_results['f1_score'].append(f1)
    fold_results['precision'].append(precision)
    fold_results['roc_auc'].append(auc)
    fold_results['log_loss'].append(logloss)
# Out:
# Fold 1
# epoch 0  | loss: 2.21002 | val_accuracy: 0.13474 | val_logloss: 1.82727 |  0:00:02s
# epoch 1  | loss: 1.99229 | val_accuracy: 0.20962 | val_logloss: 1.79063 |  0:00:03s
# epoch 2  | loss: 1.82206 | val_accuracy: 0.3232  | val_logloss: 1.66846 |  0:00:04s
# epoch 3  | loss: 1.68436 | val_accuracy: 0.36631 | val_logloss: 1.53461 |  0:00:05s
# epoch 4  | loss: 1.54544 | val_accuracy: 0.41039 | val_logloss: 1.41298 |  0:00:06s
# epoch 5  | loss: 1.42133 | val_accuracy: 0.42599 | val_logloss: 1.30514 |  0:00:07s
# epoch 6  | loss: 1.30951 | val_accuracy: 0.44716 | val_logloss: 1.17368 |  0:00:08s
# epoch 7  | loss: 1.18035 | val_accuracy: 0.64504 | val_logloss: 1.06823 |  0:00:09s
# epoch 8  | loss: 1.06969 | val_accuracy: 0.68277 | val_logloss: 0.95412 |  0:00:10s
# epoch 9  | loss: 0.96659 | val_accuracy: 0.67719 | val_logloss: 0.86247 |  0:00:11s
# epoch 10 | loss: 0.8675  | val_accuracy: 0.68431 | val_logloss: 0.78071 |  0:00:12s
# epoch 11 | loss: 0.78638 | val_accuracy: 0.71473 | val_logloss: 0.70453 |  0:00:13s
# epoch 12 | loss: 0.71292 | val_accuracy: 0.71781 | val_logloss: 0.66096 |  0:00:14s
# epoch 13 | loss: 0.66656 | val_accuracy: 0.73879 | val_logloss: 0.62433 |  0:00:15s
# epoch 14 | loss: 0.61781 | val_accuracy: 0.75457 | val_logloss: 0.59479 |  0:00:16s
# epoch 15 | loss: 0.59353 | val_accuracy: 0.76785 | val_logloss: 0.55937 |  0:00:17s
# epoch 16 | loss: 0.54799 | val_accuracy: 0.77344 | val_logloss: 0.54649 |  0:00:18s
# epoch 17 | loss: 0.53015 | val_accuracy: 0.7769  | val_logloss: 0.52917 |  0:00:19s
# epoch 18 | loss: 0.51563 | val_accuracy: 0.77806 | val_logloss: 0.51551 |  0:00:20s
# epoch 19 | loss: 0.50634 | val_accuracy: 0.78884 | val_logloss: 0.50056 |  0:00:21s
# epoch 20 | loss: 0.48985 | val_accuracy: 0.78595 | val_logloss: 0.49479 |  0:00:22s
# epoch 21 | loss: 0.46969 | val_accuracy: 0.79423 | val_logloss: 0.48552 |  0:00:23s
# epoch 22 | loss: 0.47531 | val_accuracy: 0.78749 | val_logloss: 0.48994 |  0:00:24s
# epoch 23 | loss: 0.46712 | val_accuracy: 0.80058 | val_logloss: 0.4723  |  0:00:25s
# epoch 24 | loss: 0.44723 | val_accuracy: 0.79731 | val_logloss: 0.47149 |  0:00:26s
# epoch 25 | loss: 0.44064 | val_accuracy: 0.80346 | val_logloss: 0.46183 |  0:00:27s
# epoch 26 | loss: 0.44854 | val_accuracy: 0.79923 | val_logloss: 0.46647 |  0:00:28s
# epoch 27 | loss: 0.43579 | val_accuracy: 0.80731 | val_logloss: 0.45542 |  0:00:29s
# epoch 28 | loss: 0.42254 | val_accuracy: 0.80693 | val_logloss: 0.45669 |  0:00:30s
# epoch 29 | loss: 0.4246  | val_accuracy: 0.80828 | val_logloss: 0.44958 |  0:00:31s
# epoch 30 | loss: 0.42381 | val_accuracy: 0.81347 | val_logloss: 0.44567 |  0:00:32s
# epoch 31 | loss: 0.41663 | val_accuracy: 0.80731 | val_logloss: 0.45265 |  0:00:33s
# epoch 32 | loss: 0.40717 | val_accuracy: 0.81482 | val_logloss: 0.43778 |  0:00:34s
# epoch 33 | loss: 0.41216 | val_accuracy: 0.81771 | val_logloss: 0.43184 |  0:00:35s
# epoch 34 | loss: 0.41097 | val_accuracy: 0.81482 | val_logloss: 0.43793 |  0:00:36s
# epoch 35 | loss: 0.40488 | val_accuracy: 0.81347 | val_logloss: 0.43734 |  0:00:37s
# epoch 36 | loss: 0.40953 | val_accuracy: 0.81482 | val_logloss: 0.43543 |  0:00:38s
# epoch 37 | loss: 0.39559 | val_accuracy: 0.81906 | val_logloss: 0.4245  |  0:00:38s
# epoch 38 | loss: 0.39838 | val_accuracy: 0.81906 | val_logloss: 0.427   |  0:00:39s
# epoch 39 | loss: 0.39952 | val_accuracy: 0.81521 | val_logloss: 0.43169 |  0:00:40s
# epoch 40 | loss: 0.39805 | val_accuracy: 0.82445 | val_logloss: 0.41542 |  0:00:41s
# epoch 41 | loss: 0.38866 | val_accuracy: 0.81809 | val_logloss: 0.41994 |  0:00:42s
# epoch 42 | loss: 0.38796 | val_accuracy: 0.82194 | val_logloss: 0.4162  |  0:00:43s
# epoch 43 | loss: 0.38631 | val_accuracy: 0.82464 | val_logloss: 0.4166  |  0:00:44s
# epoch 44 | loss: 0.38262 | val_accuracy: 0.83022 | val_logloss: 0.40457 |  0:00:45s
# epoch 45 | loss: 0.38532 | val_accuracy: 0.82464 | val_logloss: 0.41466 |  0:00:46s
# epoch 46 | loss: 0.37956 | val_accuracy: 0.83311 | val_logloss: 0.39891 |  0:00:47s
# epoch 47 | loss: 0.37326 | val_accuracy: 0.82868 | val_logloss: 0.40682 |  0:00:48s
# epoch 48 | loss: 0.37718 | val_accuracy: 0.82753 | val_logloss: 0.40891 |  0:00:49s
# epoch 49 | loss: 0.37567 | val_accuracy: 0.82599 | val_logloss: 0.41038 |  0:00:50s
# Stop training because you reached max_epochs = 50 with best_epoch = 46 and best_val_logloss = 0.39891
# Fold 1 Metrics:
# Accuracy: 0.8331, F1: 0.8238, Precision: 0.8159, LogLoss: 0.3989, AUC: 0.9701
#
# Fold 2
# epoch 0  | loss: 2.17178 | val_accuracy: 0.09875 | val_logloss: 1.83258 |  0:00:00s
# epoch 1  | loss: 1.96635 | val_accuracy: 0.20135 | val_logloss: 1.76026 |  0:00:01s
# epoch 2  | loss: 1.81405 | val_accuracy: 0.35322 | val_logloss: 1.64133 |  0:00:02s
# epoch 3  | loss: 1.65924 | val_accuracy: 0.38479 | val_logloss: 1.49241 |  0:00:03s
# epoch 4  | loss: 1.53849 | val_accuracy: 0.40346 | val_logloss: 1.38971 |  0:00:04s
# epoch 5  | loss: 1.41371 | val_accuracy: 0.43118 | val_logloss: 1.26639 |  0:00:05s
# epoch 6  | loss: 1.28599 | val_accuracy: 0.45486 | val_logloss: 1.16184 |  0:00:06s
# epoch 7  | loss: 1.185   | val_accuracy: 0.64466 | val_logloss: 1.06404 |  0:00:07s
# epoch 8  | loss: 1.06828 | val_accuracy: 0.70048 | val_logloss: 0.93338 |  0:00:08s
# epoch 9  | loss: 0.95881 | val_accuracy: 0.71838 | val_logloss: 0.83653 |  0:00:09s
# epoch 10 | loss: 0.84878 | val_accuracy: 0.723   | val_logloss: 0.74917 |  0:00:10s
# epoch 11 | loss: 0.78131 | val_accuracy: 0.73147 | val_logloss: 0.67192 |  0:00:11s
# epoch 12 | loss: 0.71347 | val_accuracy: 0.74225 | val_logloss: 0.62599 |  0:00:12s
# epoch 13 | loss: 0.66629 | val_accuracy: 0.74244 | val_logloss: 0.60611 |  0:00:13s
# epoch 14 | loss: 0.62739 | val_accuracy: 0.75515 | val_logloss: 0.57881 |  0:00:14s
# epoch 15 | loss: 0.60354 | val_accuracy: 0.76266 | val_logloss: 0.55963 |  0:00:15s
# epoch 16 | loss: 0.58543 | val_accuracy: 0.75784 | val_logloss: 0.54871 |  0:00:16s
# epoch 17 | loss: 0.55561 | val_accuracy: 0.77363 | val_logloss: 0.52738 |  0:00:17s
# epoch 18 | loss: 0.54029 | val_accuracy: 0.77517 | val_logloss: 0.52003 |  0:00:18s
# epoch 19 | loss: 0.51441 | val_accuracy: 0.77613 | val_logloss: 0.50971 |  0:00:19s
# epoch 20 | loss: 0.51385 | val_accuracy: 0.77883 | val_logloss: 0.50565 |  0:00:20s
# epoch 21 | loss: 0.50341 | val_accuracy: 0.78941 | val_logloss: 0.49109 |  0:00:21s
# epoch 22 | loss: 0.48486 | val_accuracy: 0.78422 | val_logloss: 0.4893  |  0:00:22s
# epoch 23 | loss: 0.48591 | val_accuracy: 0.78845 | val_logloss: 0.48066 |  0:00:23s
# epoch 24 | loss: 0.48346 | val_accuracy: 0.79076 | val_logloss: 0.47942 |  0:00:24s
# epoch 25 | loss: 0.4699  | val_accuracy: 0.7898  | val_logloss: 0.4723  |  0:00:25s
# epoch 26 | loss: 0.46686 | val_accuracy: 0.79018 | val_logloss: 0.47424 |  0:00:26s
# epoch 27 | loss: 0.46615 | val_accuracy: 0.80212 | val_logloss: 0.46254 |  0:00:27s
# epoch 28 | loss: 0.46373 | val_accuracy: 0.80115 | val_logloss: 0.46026 |  0:00:28s
# epoch 29 | loss: 0.45261 | val_accuracy: 0.80289 | val_logloss: 0.45621 |  0:00:29s
# epoch 30 | loss: 0.45596 | val_accuracy: 0.80597 | val_logloss: 0.45374 |  0:00:30s
# epoch 31 | loss: 0.45338 | val_accuracy: 0.79808 | val_logloss: 0.45319 |  0:00:31s
# epoch 32 | loss: 0.43916 | val_accuracy: 0.7948  | val_logloss: 0.45424 |  0:00:32s
# epoch 33 | loss: 0.44439 | val_accuracy: 0.80212 | val_logloss: 0.45166 |  0:00:33s
# epoch 34 | loss: 0.43042 | val_accuracy: 0.79711 | val_logloss: 0.45497 |  0:00:34s
# epoch 35 | loss: 0.43212 | val_accuracy: 0.80269 | val_logloss: 0.44579 |  0:00:35s
# epoch 36 | loss: 0.43253 | val_accuracy: 0.80982 | val_logloss: 0.43552 |  0:00:36s
# epoch 37 | loss: 0.42402 | val_accuracy: 0.80019 | val_logloss: 0.44568 |  0:00:37s
# epoch 38 | loss: 0.42031 | val_accuracy: 0.80751 | val_logloss: 0.4355  |  0:00:38s
# epoch 39 | loss: 0.41686 | val_accuracy: 0.80269 | val_logloss: 0.43877 |  0:00:39s
# epoch 40 | loss: 0.42108 | val_accuracy: 0.81867 | val_logloss: 0.42902 |  0:00:40s
# epoch 41 | loss: 0.42051 | val_accuracy: 0.80905 | val_logloss: 0.43692 |  0:00:41s
# epoch 42 | loss: 0.4325  | val_accuracy: 0.81983 | val_logloss: 0.42188 |  0:00:42s
# epoch 43 | loss: 0.4154  | val_accuracy: 0.80924 | val_logloss: 0.43381 |  0:00:43s
# epoch 44 | loss: 0.40878 | val_accuracy: 0.81809 | val_logloss: 0.42633 |  0:00:44s
# epoch 45 | loss: 0.41382 | val_accuracy: 0.81617 | val_logloss: 0.42219 |  0:00:45s
# epoch 46 | loss: 0.41765 | val_accuracy: 0.82098 | val_logloss: 0.42136 |  0:00:46s
# epoch 47 | loss: 0.40849 | val_accuracy: 0.81829 | val_logloss: 0.41907 |  0:00:47s
# epoch 48 | loss: 0.40645 | val_accuracy: 0.82483 | val_logloss: 0.40957 |  0:00:48s
# epoch 49 | loss: 0.40011 | val_accuracy: 0.81578 | val_logloss: 0.41955 |  0:00:49s
# Stop training because you reached max_epochs = 50 with best_epoch = 48 and best_val_logloss = 0.40957
# Fold 2 Metrics:
# Accuracy: 0.8248, F1: 0.8172, Precision: 0.8093, LogLoss: 0.4096, AUC: 0.9679
#
# Fold 3
# epoch 0  | loss: 2.1966  | val_accuracy: 0.12146 | val_logloss: 1.84571 |  0:00:00s
# epoch 1  | loss: 1.94575 | val_accuracy: 0.30125 | val_logloss: 1.73421 |  0:00:01s
# epoch 2  | loss: 1.77732 | val_accuracy: 0.34321 | val_logloss: 1.61156 |  0:00:03s
# epoch 3  | loss: 1.64883 | val_accuracy: 0.38595 | val_logloss: 1.48106 |  0:00:03s
# epoch 4  | loss: 1.51697 | val_accuracy: 0.40366 | val_logloss: 1.41574 |  0:00:04s
# epoch 5  | loss: 1.39542 | val_accuracy: 0.44273 | val_logloss: 1.29878 |  0:00:05s
# epoch 6  | loss: 1.27389 | val_accuracy: 0.47315 | val_logloss: 1.16985 |  0:00:06s
# epoch 7  | loss: 1.16258 | val_accuracy: 0.55765 | val_logloss: 1.0401  |  0:00:07s
# epoch 8  | loss: 1.04894 | val_accuracy: 0.69663 | val_logloss: 0.94803 |  0:00:08s
# epoch 9  | loss: 0.95245 | val_accuracy: 0.72146 | val_logloss: 0.8602  |  0:00:09s
# epoch 10 | loss: 0.86638 | val_accuracy: 0.71588 | val_logloss: 0.77824 |  0:00:10s
# epoch 11 | loss: 0.8014  | val_accuracy: 0.72936 | val_logloss: 0.72519 |  0:00:11s
# epoch 12 | loss: 0.73875 | val_accuracy: 0.73744 | val_logloss: 0.68329 |  0:00:12s
# epoch 13 | loss: 0.6881  | val_accuracy: 0.75496 | val_logloss: 0.63667 |  0:00:13s
# epoch 14 | loss: 0.65883 | val_accuracy: 0.75823 | val_logloss: 0.61043 |  0:00:14s
# epoch 15 | loss: 0.62815 | val_accuracy: 0.76689 | val_logloss: 0.59065 |  0:00:15s
# epoch 16 | loss: 0.5956  | val_accuracy: 0.78422 | val_logloss: 0.56519 |  0:00:16s
# epoch 17 | loss: 0.57548 | val_accuracy: 0.77844 | val_logloss: 0.56355 |  0:00:17s
# epoch 18 | loss: 0.54886 | val_accuracy: 0.78595 | val_logloss: 0.54259 |  0:00:18s
# epoch 19 | loss: 0.5391  | val_accuracy: 0.78576 | val_logloss: 0.53594 |  0:00:19s
# epoch 20 | loss: 0.5305  | val_accuracy: 0.7948  | val_logloss: 0.51387 |  0:00:20s
# epoch 21 | loss: 0.51594 | val_accuracy: 0.78999 | val_logloss: 0.51354 |  0:00:21s
# epoch 22 | loss: 0.50223 | val_accuracy: 0.79615 | val_logloss: 0.50623 |  0:00:22s
# epoch 23 | loss: 0.49368 | val_accuracy: 0.79577 | val_logloss: 0.49841 |  0:00:23s
# epoch 24 | loss: 0.48251 | val_accuracy: 0.80115 | val_logloss: 0.49144 |  0:00:24s
# epoch 25 | loss: 0.48203 | val_accuracy: 0.80481 | val_logloss: 0.48721 |  0:00:25s
# epoch 26 | loss: 0.4714  | val_accuracy: 0.8025  | val_logloss: 0.4866  |  0:00:26s
# epoch 27 | loss: 0.46941 | val_accuracy: 0.8052  | val_logloss: 0.47877 |  0:00:27s
# epoch 28 | loss: 0.46353 | val_accuracy: 0.80597 | val_logloss: 0.47283 |  0:00:28s
# epoch 29 | loss: 0.45854 | val_accuracy: 0.80443 | val_logloss: 0.46977 |  0:00:29s
# epoch 30 | loss: 0.45106 | val_accuracy: 0.80385 | val_logloss: 0.46206 |  0:00:30s
# epoch 31 | loss: 0.43673 | val_accuracy: 0.81155 | val_logloss: 0.44914 |  0:00:31s
# epoch 32 | loss: 0.43641 | val_accuracy: 0.81521 | val_logloss: 0.44593 |  0:00:32s
# epoch 33 | loss: 0.43027 | val_accuracy: 0.81501 | val_logloss: 0.44731 |  0:00:33s
# epoch 34 | loss: 0.43378 | val_accuracy: 0.81636 | val_logloss: 0.4512  |  0:00:34s
# epoch 35 | loss: 0.41932 | val_accuracy: 0.82156 | val_logloss: 0.43489 |  0:00:35s
# epoch 36 | loss: 0.41069 | val_accuracy: 0.82368 | val_logloss: 0.43188 |  0:00:36s
# epoch 37 | loss: 0.42056 | val_accuracy: 0.82387 | val_logloss: 0.42944 |  0:00:37s
# epoch 38 | loss: 0.40783 | val_accuracy: 0.82387 | val_logloss: 0.42788 |  0:00:38s
# epoch 39 | loss: 0.40464 | val_accuracy: 0.82098 | val_logloss: 0.42644 |  0:00:39s
# epoch 40 | loss: 0.40715 | val_accuracy: 0.82714 | val_logloss: 0.41631 |  0:00:40s
# epoch 41 | loss: 0.40093 | val_accuracy: 0.81424 | val_logloss: 0.42808 |  0:00:41s
# epoch 42 | loss: 0.3989  | val_accuracy: 0.82079 | val_logloss: 0.42331 |  0:00:42s
# epoch 43 | loss: 0.39394 | val_accuracy: 0.82964 | val_logloss: 0.41116 |  0:00:43s
# epoch 44 | loss: 0.39156 | val_accuracy: 0.82021 | val_logloss: 0.42147 |  0:00:44s
# epoch 45 | loss: 0.38997 | val_accuracy: 0.82907 | val_logloss: 0.40718 |  0:00:45s
# epoch 46 | loss: 0.39228 | val_accuracy: 0.81963 | val_logloss: 0.41897 |  0:00:46s
# epoch 47 | loss: 0.38337 | val_accuracy: 0.82849 | val_logloss: 0.40719 |  0:00:47s
# epoch 48 | loss: 0.37722 | val_accuracy: 0.82445 | val_logloss: 0.41459 |  0:00:48s
# epoch 49 | loss: 0.37822 | val_accuracy: 0.82868 | val_logloss: 0.40649 |  0:00:49s
# Stop training because you reached max_epochs = 50 with best_epoch = 49 and best_val_logloss = 0.40649
# Fold 3 Metrics:
# Accuracy: 0.8287, F1: 0.8221, Precision: 0.8146, LogLoss: 0.4065, AUC: 0.9719
#
# Fold 4
# epoch 0  | loss: 2.19149 | val_accuracy: 0.14052 | val_logloss: 1.84466 |  0:00:00s
# epoch 1  | loss: 1.97803 | val_accuracy: 0.28008 | val_logloss: 1.79215 |  0:00:01s
# epoch 2  | loss: 1.82858 | val_accuracy: 0.31684 | val_logloss: 1.66617 |  0:00:02s
# epoch 3  | loss: 1.69922 | val_accuracy: 0.3411  | val_logloss: 1.553   |  0:00:03s
# epoch 4  | loss: 1.56577 | val_accuracy: 0.3948  | val_logloss: 1.42823 |  0:00:04s
# epoch 5  | loss: 1.44323 | val_accuracy: 0.41367 | val_logloss: 1.3087  |  0:00:05s
# epoch 6  | loss: 1.32854 | val_accuracy: 0.52358 | val_logloss: 1.18779 |  0:00:06s
# epoch 7  | loss: 1.23419 | val_accuracy: 0.6358  | val_logloss: 1.08794 |  0:00:07s
# epoch 8  | loss: 1.11119 | val_accuracy: 0.67546 | val_logloss: 0.96813 |  0:00:08s
# epoch 9  | loss: 0.9755  | val_accuracy: 0.68989 | val_logloss: 0.84385 |  0:00:09s
# epoch 10 | loss: 0.86983 | val_accuracy: 0.71242 | val_logloss: 0.76504 |  0:00:10s
# epoch 11 | loss: 0.79349 | val_accuracy: 0.71858 | val_logloss: 0.70519 |  0:00:11s
# epoch 12 | loss: 0.72686 | val_accuracy: 0.74321 | val_logloss: 0.66045 |  0:00:12s
# epoch 13 | loss: 0.67676 | val_accuracy: 0.76785 | val_logloss: 0.62279 |  0:00:13s
# epoch 14 | loss: 0.62319 | val_accuracy: 0.76381 | val_logloss: 0.60395 |  0:00:14s
# epoch 15 | loss: 0.59206 | val_accuracy: 0.77247 | val_logloss: 0.58035 |  0:00:15s
# epoch 16 | loss: 0.57917 | val_accuracy: 0.77671 | val_logloss: 0.56746 |  0:00:16s
# epoch 17 | loss: 0.54967 | val_accuracy: 0.77305 | val_logloss: 0.55747 |  0:00:17s
# epoch 18 | loss: 0.54918 | val_accuracy: 0.78114 | val_logloss: 0.53891 |  0:00:18s
# epoch 19 | loss: 0.52664 | val_accuracy: 0.78114 | val_logloss: 0.53202 |  0:00:19s
# epoch 20 | loss: 0.51685 | val_accuracy: 0.78576 | val_logloss: 0.52285 |  0:00:20s
# epoch 21 | loss: 0.50846 | val_accuracy: 0.78556 | val_logloss: 0.51587 |  0:00:21s
# epoch 22 | loss: 0.49621 | val_accuracy: 0.7898  | val_logloss: 0.50465 |  0:00:22s
# epoch 23 | loss: 0.49199 | val_accuracy: 0.79038 | val_logloss: 0.50249 |  0:00:23s
# epoch 24 | loss: 0.47036 | val_accuracy: 0.79115 | val_logloss: 0.49732 |  0:00:24s
# epoch 25 | loss: 0.46647 | val_accuracy: 0.79423 | val_logloss: 0.48806 |  0:00:25s
# epoch 26 | loss: 0.46514 | val_accuracy: 0.79403 | val_logloss: 0.48668 |  0:00:26s
# epoch 27 | loss: 0.45692 | val_accuracy: 0.79865 | val_logloss: 0.4793  |  0:00:27s
# epoch 28 | loss: 0.44556 | val_accuracy: 0.80096 | val_logloss: 0.47109 |  0:00:28s
# epoch 29 | loss: 0.44256 | val_accuracy: 0.80558 | val_logloss: 0.46244 |  0:00:29s
# epoch 30 | loss: 0.4371  | val_accuracy: 0.80943 | val_logloss: 0.45889 |  0:00:30s
# epoch 31 | loss: 0.43    | val_accuracy: 0.80693 | val_logloss: 0.46006 |  0:00:31s
# epoch 32 | loss: 0.42525 | val_accuracy: 0.80635 | val_logloss: 0.4525  |  0:00:32s
# epoch 33 | loss: 0.42587 | val_accuracy: 0.81136 | val_logloss: 0.44985 |  0:00:33s
# epoch 34 | loss: 0.42373 | val_accuracy: 0.81655 | val_logloss: 0.44517 |  0:00:34s
# epoch 35 | loss: 0.41299 | val_accuracy: 0.82175 | val_logloss: 0.43743 |  0:00:35s
# epoch 36 | loss: 0.41145 | val_accuracy: 0.81155 | val_logloss: 0.45098 |  0:00:36s
# epoch 37 | loss: 0.42349 | val_accuracy: 0.8179  | val_logloss: 0.43879 |  0:00:37s
# epoch 38 | loss: 0.41108 | val_accuracy: 0.81752 | val_logloss: 0.43519 |  0:00:38s
# epoch 39 | loss: 0.40854 | val_accuracy: 0.81501 | val_logloss: 0.43778 |  0:00:39s
# epoch 40 | loss: 0.40538 | val_accuracy: 0.8206  | val_logloss: 0.42992 |  0:00:40s
# epoch 41 | loss: 0.40423 | val_accuracy: 0.81213 | val_logloss: 0.43621 |  0:00:41s
# epoch 42 | loss: 0.4036  | val_accuracy: 0.81598 | val_logloss: 0.42889 |  0:00:42s
# epoch 43 | loss: 0.39831 | val_accuracy: 0.82233 | val_logloss: 0.42536 |  0:00:43s
# epoch 44 | loss: 0.39031 | val_accuracy: 0.82214 | val_logloss: 0.42479 |  0:00:44s
# epoch 45 | loss: 0.39804 | val_accuracy: 0.82502 | val_logloss: 0.42034 |  0:00:45s
# epoch 46 | loss: 0.38679 | val_accuracy: 0.82329 | val_logloss: 0.42585 |  0:00:46s
# epoch 47 | loss: 0.39215 | val_accuracy: 0.82002 | val_logloss: 0.42912 |  0:00:47s
# epoch 48 | loss: 0.39121 | val_accuracy: 0.82772 | val_logloss: 0.41458 |  0:00:48s
# epoch 49 | loss: 0.38851 | val_accuracy: 0.82599 | val_logloss: 0.42017 |  0:00:49s
# Stop training because you reached max_epochs = 50 with best_epoch = 48 and best_val_logloss = 0.41458
# Fold 4 Metrics:
# Accuracy: 0.8277, F1: 0.8195, Precision: 0.8133, LogLoss: 0.4146, AUC: 0.9695
#
# Fold 5
# epoch 0  | loss: 2.18112 | val_accuracy: 0.13439 | val_logloss: 1.8445  |  0:00:00s
# epoch 1  | loss: 1.95906 | val_accuracy: 0.29014 | val_logloss: 1.75132 |  0:00:01s
# epoch 2  | loss: 1.77979 | val_accuracy: 0.36273 | val_logloss: 1.62319 |  0:00:02s
# epoch 3  | loss: 1.64358 | val_accuracy: 0.39892 | val_logloss: 1.49248 |  0:00:03s
# epoch 4  | loss: 1.50927 | val_accuracy: 0.42164 | val_logloss: 1.3712  |  0:00:04s
# epoch 5  | loss: 1.38038 | val_accuracy: 0.4459  | val_logloss: 1.261   |  0:00:05s
# epoch 6  | loss: 1.26878 | val_accuracy: 0.45803 | val_logloss: 1.16726 |  0:00:06s
# epoch 7  | loss: 1.15139 | val_accuracy: 0.49615 | val_logloss: 1.02107 |  0:00:07s
# epoch 8  | loss: 1.02991 | val_accuracy: 0.69792 | val_logloss: 0.89221 |  0:00:08s
# epoch 9  | loss: 0.92067 | val_accuracy: 0.71371 | val_logloss: 0.78838 |  0:00:09s
# epoch 10 | loss: 0.82022 | val_accuracy: 0.71602 | val_logloss: 0.7245  |  0:00:10s
# epoch 11 | loss: 0.77509 | val_accuracy: 0.73104 | val_logloss: 0.68257 |  0:00:11s
# epoch 12 | loss: 0.71639 | val_accuracy: 0.73431 | val_logloss: 0.6489  |  0:00:12s
# epoch 13 | loss: 0.67418 | val_accuracy: 0.74567 | val_logloss: 0.60892 |  0:00:13s
# epoch 14 | loss: 0.65413 | val_accuracy: 0.75818 | val_logloss: 0.58827 |  0:00:14s
# epoch 15 | loss: 0.61563 | val_accuracy: 0.7705  | val_logloss: 0.56174 |  0:00:15s
# epoch 16 | loss: 0.5919  | val_accuracy: 0.76588 | val_logloss: 0.55567 |  0:00:16s
# epoch 17 | loss: 0.58548 | val_accuracy: 0.78687 | val_logloss: 0.52852 |  0:00:17s
# epoch 18 | loss: 0.54892 | val_accuracy: 0.78937 | val_logloss: 0.51848 |  0:00:18s
# epoch 19 | loss: 0.53337 | val_accuracy: 0.78937 | val_logloss: 0.51293 |  0:00:19s
# epoch 20 | loss: 0.52282 | val_accuracy: 0.79168 | val_logloss: 0.49737 |  0:00:20s
# epoch 21 | loss: 0.50945 | val_accuracy: 0.79419 | val_logloss: 0.49406 |  0:00:21s
# epoch 22 | loss: 0.5009  | val_accuracy: 0.79861 | val_logloss: 0.48465 |  0:00:22s
# epoch 23 | loss: 0.48771 | val_accuracy: 0.79361 | val_logloss: 0.48251 |  0:00:23s
# epoch 24 | loss: 0.47611 | val_accuracy: 0.804   | val_logloss: 0.46956 |  0:00:24s
# epoch 25 | loss: 0.4674  | val_accuracy: 0.80786 | val_logloss: 0.46003 |  0:00:25s
# epoch 26 | loss: 0.46092 | val_accuracy: 0.79804 | val_logloss: 0.45988 |  0:00:26s
# epoch 27 | loss: 0.46386 | val_accuracy: 0.80882 | val_logloss: 0.45023 |  0:00:27s
# epoch 28 | loss: 0.45618 | val_accuracy: 0.82152 | val_logloss: 0.43501 |  0:00:28s
# epoch 29 | loss: 0.44154 | val_accuracy: 0.81556 | val_logloss: 0.43765 |  0:00:29s
# epoch 30 | loss: 0.44842 | val_accuracy: 0.82075 | val_logloss: 0.43485 |  0:00:30s
# epoch 31 | loss: 0.43008 | val_accuracy: 0.8171  | val_logloss: 0.4348  |  0:00:31s
# epoch 32 | loss: 0.4295  | val_accuracy: 0.81729 | val_logloss: 0.43212 |  0:00:32s
# epoch 33 | loss: 0.41679 | val_accuracy: 0.82345 | val_logloss: 0.42509 |  0:00:33s
# epoch 34 | loss: 0.41786 | val_accuracy: 0.83423 | val_logloss: 0.41587 |  0:00:34s
# epoch 35 | loss: 0.415   | val_accuracy: 0.8221  | val_logloss: 0.42585 |  0:00:35s
# epoch 36 | loss: 0.41326 | val_accuracy: 0.83481 | val_logloss: 0.41296 |  0:00:36s
# epoch 37 | loss: 0.40512 | val_accuracy: 0.82749 | val_logloss: 0.41807 |  0:00:37s
# epoch 38 | loss: 0.39727 | val_accuracy: 0.83712 | val_logloss: 0.40509 |  0:00:38s
# epoch 39 | loss: 0.40409 | val_accuracy: 0.82692 | val_logloss: 0.41615 |  0:00:39s
# epoch 40 | loss: 0.3951  | val_accuracy: 0.83673 | val_logloss: 0.39984 |  0:00:39s
# epoch 41 | loss: 0.39255 | val_accuracy: 0.83693 | val_logloss: 0.39567 |  0:00:40s
# epoch 42 | loss: 0.38778 | val_accuracy: 0.8402  | val_logloss: 0.39122 |  0:00:41s
# epoch 43 | loss: 0.3927  | val_accuracy: 0.83943 | val_logloss: 0.39154 |  0:00:42s
# epoch 44 | loss: 0.38653 | val_accuracy: 0.83673 | val_logloss: 0.39498 |  0:00:43s
# epoch 45 | loss: 0.38165 | val_accuracy: 0.84251 | val_logloss: 0.38525 |  0:00:44s
# epoch 46 | loss: 0.38013 | val_accuracy: 0.84463 | val_logloss: 0.38353 |  0:00:45s
# epoch 47 | loss: 0.38859 | val_accuracy: 0.84713 | val_logloss: 0.37808 |  0:00:46s
# epoch 48 | loss: 0.38018 | val_accuracy: 0.84444 | val_logloss: 0.38127 |  0:00:47s
# epoch 49 | loss: 0.38151 | val_accuracy: 0.8454  | val_logloss: 0.37858 |  0:00:48s
# Stop training because you reached max_epochs = 50 with best_epoch = 47 and best_val_logloss = 0.37808
# Fold 5 Metrics:
# Accuracy: 0.8471, F1: 0.8387, Precision: 0.8301, LogLoss: 0.3781, AUC: 0.9749

# %%
# Menyimpan model terbaik pada database
if best_model is not None:
    if n_epochs == 100 and n_patience == 15:
        best_model_path = f"/content/drive/MyDrive/Model_Skripsi/TabNet/epoch_100/CIC-IoT-2023_tabnet__best_model_fold{best_fold}_logloss{best_logloss:.6f}"
    elif n_epochs == 50 and n_patience == 15:
        best_model_path = f"/content/drive/MyDrive/Model_Skripsi/TabNet/epoch_50/CIC-IoT-2023_tabnet_best_model_fold{best_fold}_logloss{best_logloss:.6f}"


    best_model.save_model(best_model_path)
    print(f"Model terbaik disimpan dari Fold {best_fold} dengan logloss: {best_logloss:.6f}")
# Out:
# Successfully saved model at /content/drive/MyDrive/Model_Skripsi/TabNet/epoch_50/CIC-IoT-2023_tabnet_best_model_fold5_logloss0.378076.zip
# Model terbaik disimpan dari Fold 5 dengan logloss: 0.378076

# %%
# Menampilkan visualisasi kurva logloss per epoch pada setiap fold
functions.plot_curve(fold_logloss_curve, metric_name="Validation LogLoss")

# %%
# Menampilkan visualisasi kurva accuracy per epoch pada setiap fold
functions.plot_curve(fold_accuracy_curve, metric_name="Validation Accuracy")

# %%
# Menampilkan rata-rata semua metrik dari semua fold
print("\nRata-Rata Hasil Cross Validation:")
for metric in ['accuracy', 'f1_score', 'precision', 'roc_auc', 'log_loss']:
    avg_value = np.mean([val for val in fold_results[metric] if val is not None])
    print(f"{metric}: {avg_value:.4f}")
# Out:
# Rata-Rata Hasil Cross Validation:
# accuracy: 0.8323
# f1_score: 0.8242
# precision: 0.8166
# roc_auc: 0.9709
# log_loss: 0.4015

# %%
# Menampilkan visualisasi keakuratan prediksi model
functions.plot_best_confusion_matrix(best_y_true, best_preds, best_fold)
